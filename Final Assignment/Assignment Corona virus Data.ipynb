# %% [markdown]
# ### Assignment 2023

# %% [raw]
# Deadline Fri 21st July, 5 pm

# %% [markdown]
# # Coronavirus Country Profiles. Application for the Corona virus crisis: Python, Data and trends

# %% [markdown]
# This assigment will enhance your skills in reading data files,
# plotting a few dependencies and analysis the results. A curve fitting of the data with a
# Gaussian model will enhance your ability to model the observed data.
# The assignment is a wonderful skill to have for future research and work.
#
#
# MARKS AND STRUCTURE:
#
# The assignment has 5 Tasks (TOTAL=10 marks)
# * 1. Task 1 Get the data (3)
# * 2. Task 2 Read the data and plot these for two countries of your own choice (2)
# * 3. Task 3 Analysis (basic) (1)
# * 4. Task 4 Generate a function to reproduce the flatenning of the corona virus curve (2)
# * 5. Task 5 Fit the existing daily case of corona virus with a Gaussian model (2)

# %% [markdown]
# # Introduction

# %% [markdown]
# Coronavirus is continuing its spread across the world. The outbreak was declared a global pandemic by the World Health Organization (WHO) on 11 March 2020.

# %% [markdown]
# In this assignment you will access a data file, available on line, with all updates information on the   corona virus for all countries of the world. You will read the data into this worksheet, you will filter the data by choosing two countries to study  (do not use  Australia, as I use this as an example).
#
# Then you will analyse the data, by plotting dependencies, time series and asking each of the following :
#
# * What is the number of infections/cases per day?
# * Total confirmed deaths: how rapidly have they increased/decreased compared to other countries?
# * What is the daily number of infections?
# * What is the daily number of confirmed deaths?
# * Daily confirmed deaths: are we bending the curve?
# * Daily confirmed deaths: when did countries bend the curve?
#
# All your answers will be derived from graphics or analysis which has to be shown above your answers.
#
# Then you will try to fit the data with a Gaussian (bell curve)
#
# See how your country is affected by the COVID-19 pandemic and how it compares to others.
#
#
# Good luck!

# %% [markdown]
# # Resources:

# %% [markdown]
# The data used on this page comes from a variety of sources. It includes figures collated by Johns Hopkins University, data from the European Centre for Disease Prevention and Control, national governments and health agencies, as well as UN data on populations.

# %% [markdown]
# https://ourworldindata.org/grapher/covid-daily-vs-total-cases

# %% [markdown]
# https://ourworldindata.org/grapher/daily-cases-covid-19

# %% [markdown]
# https://ourworldindata.org/grapher/covid-confirmed-daily-cases-epidemiological-trajectory

# %% [markdown]
# https://ourworldindata.org/grapher/school-closures-covid

# %% [markdown]
# Flattening the pandemic and recession curves
# Pierre-Olivier Gourinchas 03 June 2020:
#
#     https://voxeu.org/article/flattening-pandemic-and-recession-curves

# %% [markdown]
# Coronavirus: What is 'flattening the curve,' and will it work?
#
#     https://www.livescience.com/coronavirus-flatten-the-curve.html

# %% [markdown]
# In Italy, for example — the country with the worst COVID-19 outbreak outside of China — confirmed cases doubled from 10,000 to 20,000 in just four days (March 11 to March 15). The faster the infection curve rises, the quicker the local health care system gets overloaded beyond its capacity to treat people. As we're seeing in Italy, more and more new patients may be forced to go without ICU beds, and more and more hospitals may run out of the basic supplies they need to respond to the outbreak.

# %% [markdown]
# # Task 1: Accessing the data for the Coronavirus Country Profiles

# %% [markdown]
# Importing data is the first step in any data science project. Download the latest from:
#
# https://github.com/owid/covid-19-data/blob/master/public/data/owid-covid-data.csv
#
# Read more
#
# https://github.com/owid/covid-19-data/tree/master/public/data
#
# The data on the coronavirus pandemic is updated daily.
#
# Learn why today's data scientists prefer pandas' read_csv() function to do this.

# %% [markdown]
# Note: Source of data: https://github.com/owid/covid-19-data/tree/master/public/data/
#
#
# If you work with this data file, you must upload the latest updated version of it.

# %% [markdown]
# ### Question 1: Read your data file owid-covid-data.csv and show the header of the file

# %%
import pandas as pd # Import the correct library

covid_df = pd.read_csv('owid-covid-data.csv')  # Read the file owid-covid-data

covid_df.head() # Read the header of your file
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1      AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2      AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3      AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4      AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %% [markdown]
# Note: As of 3rd June 2020, the columns are: iso_code, location, date, total_cases, new_cases, total_deaths, new_deaths, total_cases_per_million, new_cases_per_million, total_deaths_per_million, new_deaths_per_million, total_tests, new_tests, total_tests_per_thousand, new_tests_per_thousand, tests_units
#
# It is up to you to prospect the datafile and learn about its data.

# %% [markdown]
# ###  Question 2 Find what type of data you have in the large table and decide which variables are of interest for you

# %% [markdown]
# Learn about the types of columns in the data file:

# %%
print('Columns in the dataframe:')
print(covid_df.columns) # To see how are named the columns of the df

print('_______________________________________________________________________________________________________')

print('The data type of each column is the following, also we include the number of non-null entries:')
covid_df.info(verbose = True) # To see the data types of each column and number of NaN values in each column
# Out:
# Columns in the dataframe:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %% [markdown]
# I would like to study the number of cases and deaths over time, how the new cases and new deaths changed over time, to do that I'll only need the following columns:
#
#     - location
#     - date
#     - total_cases
#     - total_deaths
#     - new_cases
#     - new_deaths
#
# Whith this information one can get curves associated with the behaviour of covid over time, also find the peaks where the dissease will decrease and plan how to get that peak faster with less cases and deaths.

# %% [markdown]
# ### Question 3: Which two countries do you choose to analyse?

# %% [markdown]
# Country 1: Colombia

# %% [markdown]
# Country 2: Australia

# %% [markdown]
# * Note: When comparing figures from different countries it is important to bear in mind that not all governments are recording coronavirus cases and deaths in the same way. This makes like for like comparisons between countries difficult. But for the purpose of this assignment we will compare graphics without going into the politics.
#
# * Other factors to consider include: different population sizes, the size of the a country's elderly population or whether a particular country has a large amount of its people living in densely populated areas. We will not go into such details.
#
# * In addition, countries may be in different stages of the pandemic and this may be seen from the corona virus curves and can be analysed in this assignment.

# %% [markdown]
# ### Question 4: Which rows in the table correspond to your countries?

# %%
# df for Colombia
colombia_df = covid_df.loc[covid_df['location'] ==  'Colombia'] # Get only the data for Colombia
colombia_df = colombia_df[['location','date','total_cases','total_deaths','new_cases','new_deaths']] # Get only the columns of interest

print('The number of total entries for Colombia is:')
print(colombia_df.shape[0]) # Total of entries for Colombia

print('First element in the dataframe (date and number in the big df)')
print(colombia_df.iloc[0]) # First row

print('Last element in the dataframe (date and number in the big df)')
print(colombia_df.iloc[-1]) # Last row
# Out:
# The number of total entries for Colombia is:
# 1287
# First element in the dataframe (date and number in the big df)
# location          Colombia
# date            2020-01-03
# total_cases            NaN
# total_deaths           NaN
# new_cases              0.0
# new_deaths             0.0
# Name: 57917, dtype: object
# Last element in the dataframe (date and number in the big df)
# location          Colombia
# date            2023-07-12
# total_cases      6374521.0
# total_deaths      142861.0
# new_cases              NaN
# new_deaths             NaN
# Name: 59203, dtype: object

# %%
# df for Australia
australia_df = covid_df.loc[covid_df['location'] ==  'Australia'] # Get only the data for Colombia
australia_df = australia_df[['location','date','total_cases','total_deaths','new_cases','new_deaths']] # Get only the columns of interest

print('The number of total entries for australia is:')
print(australia_df.shape[0]) # Total of entries for Australia

print('First element in the dataframe (date and number in the big df)')
print(australia_df.iloc[0]) # First row

print('Last element in the dataframe (date and number in the big df)')
print(australia_df.iloc[-1]) # Last row
# Out:
# The number of total entries for australia is:
# 1287
# First element in the dataframe (date and number in the big df)
# location         Australia
# date            2020-01-03
# total_cases            NaN
# total_deaths           NaN
# new_cases              0.0
# new_deaths             0.0
# Name: 16733, dtype: object
# Last element in the dataframe (date and number in the big df)
# location         Australia
# date            2023-07-12
# total_cases     11519171.0
# total_deaths       22076.0
# new_cases              0.0
# new_deaths             0.0
# Name: 18019, dtype: object

# %% [markdown]
# ### Answer:

# %% [markdown]
# Country 1: 57917 - 59203

# %% [markdown]
# Country 2: 16733 - 18019

# %% [markdown]
# # Task 2: Present your data for two countries. Number of daily infectious cases in your country . Which curves have flattened?

# %% [markdown]
# The typical curve we are talking about is one that shows the number of new COVID-19 cases per day across the country. Flattening it means fewer new cases each day, so the number of current cases comes down, reducing demand on services.
#
# For biological systems, the exponential growth curve gives way to the normal distribution or bell curve as the growth pattern begins to decrease. For COVID-19, the bell curve refers to the projected number of people that will contact the virus over a period of time – from the start to the finish.
#
# The peak of the bell curve refers to the total number of people infected with the virus during the pandemic. The width of the bell is controlled by the standard deviation, which is a measure of the amount of variation for a data set. A low standard deviation indicates that the data points tend to be close to the mean – making the bell curve high and narrow. Conversely, a high standard deviation indicates that the data points are spread out over a wider range from the mean.
#
# Mathematically, flattening the curve requires an increase in the standard deviation. Healthwise, a flatter curve leads to a lower rate of infection so the pandemic is spread out over time, thus giving health professionals a reasonable chance at treating all of the sick people with the available resources.

# %% [markdown]
# ### Question 1: Plot the number of total infections in your country versus time (dates!).

# %% [markdown]
# From the original huge datafile you must extract the data for a specific country (not Australia, as I am doing this for teaching purposes). So, for Australia I am choosing only the raws corresponding to this country. I am interested in the number of total cases of infection.

# %% [markdown]
# Reminder: For a Basic reading of a datafile with two columns of data we will usually do:
#
# data = loadtxt('model1d_gauss.dat')
#
# x = data[:, 0]
#
# y = data[:, 1]
#
# But for a csv file, we use the iloc sorting command.

# %%
#Look into the big data file and extract the number of rows of your  countries 
# it can be done automatically

number_first = 57917 # First row where Colombia appears
number_last = 59203 # Last row where Colombia appears

#extract  all the data for your country , raws and columns
extract = covid_df.iloc[number_first:number_last+1]

print('Number of entries with NaN values:')
print(len(extract))

extract= extract[['date','new_cases','new_deaths','total_deaths','total_cases_per_million','total_cases']]

print('Number of entries without NaN values:')
extract = extract.dropna() # Drop NaN values

print(len(extract))

extract.head() # Show first 5 rows of my extracted df
# Out:
# Number of entries with NaN values:
# 1287
# Number of entries without NaN values:
# 1203
#              date  new_cases  new_deaths  total_deaths  \
# 57997  2020-03-23        0.0         2.0           2.0
# 57998  2020-03-24       81.0         1.0           3.0
# 57999  2020-03-25       29.0         0.0           3.0
# 58000  2020-03-26       72.0         0.0           3.0
# 58001  2020-03-27       92.0         1.0           4.0
#
#        total_cases_per_million  total_cases
# 57997                    3.778        196.0
# 57998                    5.340        277.0
# 57999                    5.899        306.0
# 58000                    7.287        378.0
# 58001                    9.060        470.0

# %%
# Look at new cases, total caes, deaths, etc...
#quick plots

australia = covid_df.loc[covid_df['location'] ==  'Australia'] # Get only the data for Colombia
australia = australia[['location','date','total_cases','total_deaths','new_cases','new_deaths','total_cases_per_million']] # Get only the columns of interest

colombia = covid_df.loc[covid_df['location'] ==  'Colombia'] # Get only the data for Colombia
colombia = colombia[['location','date','total_cases','total_deaths','new_cases','new_deaths','total_cases_per_million']] # Get only the columns of interest

# Get relevant information from the df
def get_info(extract):
    
    new_cases = extract['new_cases']
    new_deaths = extract['new_deaths']
    total_deaths = extract['total_deaths']
    total_cases_per_million = extract['total_cases_per_million']
    total_cases = extract['total_cases']
    dates = pd.to_datetime(extract['date'])
    
    return new_cases,new_deaths,total_deaths,total_cases_per_million,total_cases,dates

au_nc,au_nd,au_td,au_tcm,au_tc,au_d = get_info(australia)
co_nc,co_nd,co_td,co_tcm,co_tc,co_d = get_info(colombia)

print(co_d)
# Out:
# 57917   2020-01-03
# 57918   2020-01-04
# 57919   2020-01-05
# 57920   2020-01-06
# 57921   2020-01-07
#            ...
# 59199   2023-07-08
# 59200   2023-07-09
# 59201   2023-07-10
# 59202   2023-07-11
# 59203   2023-07-12
# Name: date, Length: 1287, dtype: datetime64[ns]

# %% [markdown]
# * Make a  plot of number of total infections in your country  versus time with scatter plot to retain the dates on the x axis. If the graph is too crowded enlarge it.
#
# * Label the plot, Title it.
#
# Hint: Read the hint on elegant way of presenting reformatted dates, and the end of the worksheet.

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# %%
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter

matplotlib.rcParams.update({'font.size': 18, 'text.usetex': True})

fig, ax = plt.subplots(2,1)
fig.set_size_inches(15, 21, forward=True)
#fig.autofmt_xdate()

plt.ticklabel_format(style='sci', axis='y', scilimits=(6,6),useMathText=True)

s = np.ones(len(co_d))

ax[0].scatter(co_d, co_tc, color = 'green', s = 5*s)

ax[0].set(ylabel = "Total cases", title = "Colombia")

# Format the x axis
ax[0].xaxis.set_major_locator(mdates.MonthLocator(interval=3))
ax[0].xaxis.set_major_formatter(DateFormatter("%Y-%m-%d"))
ax[0].tick_params(axis='x',rotation=45)

fig.subplots_adjust(hspace= 0.3)

ax[1].scatter(au_d, au_tc, color = 'blue', s = 5*s)

ax[1].set(ylabel = "Total cases", title = "Australia")

# Format the x axis
ax[1].xaxis.set_major_locator(mdates.MonthLocator(interval=3))
ax[1].xaxis.set_major_formatter(DateFormatter("%Y-%m-%d"))
ax[1].tick_params(axis='x',rotation=45)

plt.show()

# %% [markdown]
# Too much data?!Markers on axes not visible ?! Do not leave it like this! We want to be able to read the dates on the x axis. You must change this:
# * either changing fonts, or
# * choosing a smaller domain of dates, perhaps removing some of the flat data at the beginning of the pandemics.
#
# Follow also the hints "Fixing common date annoyances" for nice plots.

# %% [markdown]
# ### Question 2: Plot the number of new_cases in your country versus time ( real dates).

# %%
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter

matplotlib.rcParams.update({'font.size': 18, 'text.usetex': True})

fig, ax = plt.subplots(2,1)
fig.set_size_inches(15, 21, forward=True)
#fig.autofmt_xdate()

plt.ticklabel_format(style='sci', axis='y', scilimits=(6,6),useMathText=True)

s = np.ones(len(co_d))

ax[0].scatter(co_d, co_nc, color = 'gold', s = 5*s)

ax[0].set(ylabel = "New cases", title = "Colombia")

# Format the x axis
ax[0].xaxis.set_major_locator(mdates.MonthLocator(interval=3))
ax[0].xaxis.set_major_formatter(DateFormatter("%Y-%m-%d"))
ax[0].tick_params(axis='x',rotation=45)

fig.subplots_adjust(hspace= 0.3)

ax[1].scatter(au_d, au_nc, color = 'magenta', s = 5*s)

ax[1].set(ylabel = "New cases", title = "Australia")

# Format the x axis
ax[1].xaxis.set_major_locator(mdates.MonthLocator(interval=3))
ax[1].xaxis.set_major_formatter(DateFormatter("%Y-%m-%d"))
ax[1].tick_params(axis='x',rotation=45)

plt.show()

# %% [markdown]
# ### Question  3: Plot the number of new deaths in your country  versus time ( real dates)

# %%
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter

matplotlib.rcParams.update({'font.size': 18, 'text.usetex': True})

fig, ax = plt.subplots(2,1)
fig.set_size_inches(15, 21, forward=True)
#fig.autofmt_xdate()

plt.ticklabel_format(style='sci', axis='y', scilimits=(6,6),useMathText=True)

s = np.ones(len(co_d))

ax[0].scatter(co_d, co_nd, color = 'lightblue', s = 5*s)

ax[0].set(ylabel = "New deaths", title = "Colombia")

# Format the x axis
ax[0].xaxis.set_major_locator(mdates.MonthLocator(interval=3))
ax[0].xaxis.set_major_formatter(DateFormatter("%Y-%m-%d"))
ax[0].tick_params(axis='x',rotation=45)

fig.subplots_adjust(hspace= 0.3)

ax[1].scatter(au_d, au_nd, color = 'silver', s = 5*s)

ax[1].set(ylabel = "New deaths", title = "Australia")

# Format the x axis
ax[1].xaxis.set_major_locator(mdates.MonthLocator(interval=3))
ax[1].xaxis.set_major_formatter(DateFormatter("%Y-%m-%d"))
ax[1].tick_params(axis='x',rotation=45)

plt.show()

# %% [markdown]
# ### Question 4: Plot the number of total death  in your country versus time ( dates).

# %%
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter

matplotlib.rcParams.update({'font.size': 18, 'text.usetex': True})

fig, ax = plt.subplots(2,1)
fig.set_size_inches(15, 21, forward=True)
#fig.autofmt_xdate()

plt.ticklabel_format(style='sci', axis='y', scilimits=(6,6),useMathText=True)

s = np.ones(len(co_d))

ax[0].scatter(co_d, co_td, color = 'orange', s = 5*s)

ax[0].set(ylabel = "Total deaths", title = "Colombia")

# Format the x axis
ax[0].xaxis.set_major_locator(mdates.MonthLocator(interval=3))
ax[0].xaxis.set_major_formatter(DateFormatter("%Y-%m-%d"))
ax[0].tick_params(axis='x',rotation=45)

fig.subplots_adjust(hspace= 0.3)

ax[1].scatter(au_d, au_td, color = 'darkred', s = 5*s)

ax[1].set(ylabel = "Total deaths", title = "Australia")

# Format the x axis
ax[1].xaxis.set_major_locator(mdates.MonthLocator(interval=3))
ax[1].xaxis.set_major_formatter(DateFormatter("%Y-%m-%d"))
ax[1].tick_params(axis='x',rotation=45)

plt.show()

# %% [markdown]
# # Task 3:  Analysis: Answer the following questions:

# %% [markdown]
# ### Question 1: When did the covid data start being recorded for your countries

# %%
print('First day of recording:')
print(co_d.iloc[0]) # First day of recording
# Out:
# First day of recording:
# 2020-01-03 00:00:00

# %% [markdown]
# Answer 1: 2020-03-23

# %% [markdown]
# Answer 2: 2020-03-23

# %% [markdown]
# ### Question 2: Which date corresponds for a maximum in the number of cases in your countries? (if there are more peaks, mention all of them)

# %%
from scipy.signal import find_peaks
colombia_peaks = find_peaks(co_nc,distance=75)[0]+57917
australia_peaks = find_peaks(au_nc,distance=75)[0]+16733
print('max number of new cases:')
print('Colombia: ',co_nc[colombia_peaks]) # Peaks number of cases for Colombia
print('Dates: ',co_d[colombia_peaks])

print('__________________________________________________________________________________')

print('max number of new cases:')
print('Australia: ',au_nc[australia_peaks]) # Peaks number of cases for Australia
print('Dates: ',au_d[australia_peaks])
# Out:
# max number of new cases:
# Colombia:  57996       68.0
# 58072     1766.0
# 58148    13056.0
# 58297    21078.0
# 58383    17483.0
# 58459    33594.0
# 58556     1867.0
# 58662    35575.0
# 58737      365.0
# 58842    24649.0
# 58919      820.0
# 59003     7930.0
# 59079      691.0
# 59165     1334.0
# Name: new_cases, dtype: float64
# Dates:  57996   2020-03-22
# 58072   2020-06-06
# 58148   2020-08-21
# 58297   2021-01-17
# 58383   2021-04-13
# 58459   2021-06-28
# 58556   2021-10-03
# 58662   2022-01-17
# 58737   2022-04-02
# 58842   2022-07-16
# 58919   2022-10-01
# 59003   2022-12-24
# 59079   2023-03-10
# 59165   2023-06-04
# Name: date, dtype: datetime64[ns]
# __________________________________________________________________________________
# max number of new cases:
# Australia:  16817       562.0
# 16943       721.0
# 17018        31.0
# 17097        46.0
# 17209        37.0
# 17295       875.0
# 17372     15401.0
# 17470    588813.0
# 17554    395982.0
# 17667    319779.0
# ...

# %%
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter

matplotlib.rcParams.update({'font.size': 18, 'text.usetex': True})

fig, ax = plt.subplots(2,1)
fig.set_size_inches(15, 21, forward=True)
#fig.autofmt_xdate()

plt.ticklabel_format(style='sci', axis='y', scilimits=(6,6),useMathText=True)

s = np.ones(len(co_d))

ax[0].scatter(co_d, co_nc, color = 'gold', s = 5*s)
ax[0].scatter(co_d[colombia_peaks],co_nc[colombia_peaks], marker='x', color='darkred')

ax[0].set(ylabel = "New cases", title = "Colombia")

# Format the x axis
ax[0].xaxis.set_major_locator(mdates.MonthLocator(interval=3))
ax[0].xaxis.set_major_formatter(DateFormatter("%Y-%m-%d"))
ax[0].tick_params(axis='x',rotation=45)

fig.subplots_adjust(hspace= 0.3)

ax[1].scatter(au_d, au_nc, color = 'magenta', s = 5*s)
ax[1].scatter(au_d[australia_peaks],au_nc[australia_peaks], marker='x', color='royalblue')

ax[1].set(ylabel = "New cases", title = "Australia")

# Format the x axis
ax[1].xaxis.set_major_locator(mdates.MonthLocator(interval=3))
ax[1].xaxis.set_major_formatter(DateFormatter("%Y-%m-%d"))
ax[1].tick_params(axis='x',rotation=45)

plt.show()

# %% [markdown]
# Answer 1: Look at the amazing graphs!

# %% [markdown]
# Answer 2: Look at the amazing graphs!

# %% [markdown]
# There are also prints with the values of the peaks ploted as 'x' in the graphics

# %% [markdown]
# ### Question 3: Compare the two countries, by plotting on the same plot  both curves,  for the  daily number of reported cases and total number of cases. (if the curves are far away in time from each other, you may want to translate your data left or right)

# %%
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter

matplotlib.rcParams.update({'font.size': 18, 'text.usetex': True})

fig, ax = plt.subplots(2,1)
fig.set_size_inches(15, 21, forward=True)
#fig.autofmt_xdate()

plt.ticklabel_format(style='sci', axis='y', scilimits=(6,6),useMathText=True)

s = np.ones(len(co_d))

ax[0].scatter(co_d, co_nc, color = 'gold', s = 10*s ,label='Colombia')
ax[0].scatter(au_d, au_nc, color = 'royalblue', s = 10*s, label='Australia')

ax[0].set(ylabel = "New cases")

# Format the x axis
ax[0].xaxis.set_major_locator(mdates.MonthLocator(interval=3))
ax[0].xaxis.set_major_formatter(DateFormatter("%Y-%m-%d"))
ax[0].tick_params(axis='x',rotation=45)

fig.subplots_adjust(hspace= 0.3)

ax[0].legend()

ax[1].scatter(co_d, co_tc, color = 'gold', s = 10*s, label='Colombia')
ax[1].scatter(au_d, au_tc, color = 'royalblue', s = 10*s, label='Australia')

ax[1].set(ylabel = "Total cases")

# Format the x axis
ax[1].xaxis.set_major_locator(mdates.MonthLocator(interval=3))
ax[1].xaxis.set_major_formatter(DateFormatter("%Y-%m-%d"))
ax[1].tick_params(axis='x',rotation=45)

ax[1].legend()

plt.show()

# %% [markdown]
# ### Question 4: What do you think will happen to your countries and their corona virus cases  in the next 6 months?

# %% [markdown]
# As we already showed in the graph the number of total cases will continue growing and the behaviour of the curves tell us that the increasing will be slow (in terms of total cases), for the new cases graph we can see that there are peaks sparsed in time so for the next six months won't be surprising that a new peak can appear.

# %% [markdown]
# # Task 4: Modelling the Corona Virus Data and Bell-Shape/Gaussian Curve Fitting for ONLY ONE of your Countries

# %% [markdown]
# Find a Gaussian Curve Model for the the daily total cases of corona virus for ONE OF YOUR countries with a Gaussian shape function.
#
# What is the best model of a Gaussian for your curves? (print(result.fit_report()))
#
# Complete the code below to find out the best model for the curve of your country.

# %% [markdown]
# First Country:

# %%
#Generate arrays x and y from our data to be used later in the fitting model.
#For Australia the number of max data is 154 (raws). 

y = co_nc.iloc[720:780]

print(y)

x = np.arange(0,60,1)

#print('x=',x)

print('x = ',x)

##########################################

#import ________
from numpy import exp, loadtxt, pi, sqrt
from scipy.optimize import curve_fit



#define the curve as a Gaussian that we want to fit the data
def gaussian(x, amp, cen, wid):
    """1-d gaussian: gaussian(x, amp, cen, wid)"""
    return amp*np.exp(-((x-cen)/wid)**2)

#we create an initial model Model amp=100, cen=90, wid=2 or any of your best guesses


# gmodel = ____________
# result = _____________

# print(result.fit_report())

# fig, ax = plt.___________(figsize=(20, 10))

# plt.plot(x, y, 'bo')
# plt.plot(x, result.______, 'k--', label='initial fit')
# plt.plot(x, _______.best_fit, 'r-', label='best fit')
# plt.legend(loc='best')
# plt._________()


parameters, covariance = curve_fit(gaussian, x, y)
  
fit_A = parameters[0]
fit_B = parameters[1]
fit_C = parameters[2]
  
fit_y = gaussian(x, fit_A, fit_B, fit_C)
plt.plot(x, y.to_list(), 'o', label='data')
plt.plot(x, fit_y, '-', label='fit')
plt.legend()
plt.show()
# Out:
# 58637     1766.0
# 58638     1931.0
# 58639     2475.0
# 58640     3060.0
# 58641     3414.0
# 58642     3022.0
# 58643     3281.0
# 58644     4306.0
# 58645     6326.0
# 58646     8436.0
# 58647    10401.0
# 58648    12415.0
# 58649    11318.0
# 58650     9848.0
# 58651    12353.0
# 58652    16259.0
# 58653    23039.0
# 58654    26190.0
# 58655    31170.0
# 58656    30630.0
# 58657    27105.0
# 58658    23074.0
# 58659    29857.0
# 58660    30283.0
# 58661    34923.0
# 58662    35575.0
# 58663    32317.0
# 58664    24272.0
# 58665    28849.0
# 58666    27603.0
# 58667    30506.0
# 58668    31039.0
# 58669    28027.0
# 58670    26087.0
# 58671    21219.0
# 58672    19512.0
# 58673    17889.0
# 58674    17663.0
# 58675    20946.0
# 58676    18450.0
# 58677    16119.0
# 58678    15284.0
# 58679    14454.0
# 58680    15110.0
# 58681    13568.0
# 58682    13390.0
# 58683    12567.0
# 58684    10356.0
# 58685     9080.0
# 58686     9730.0
# 58687     8785.0
# 58688     8269.0
# ...

# %% [markdown]
# Question:
#
#     So, what is the best model of a Gaussian for your curves? Write its mathematical expression below:

# %% [markdown]
# $p(x) = -30361.115 \, e^{-\left( \frac{x-27.280}{17.361} \right)^{2}}$

# %%
print('amp: ',fit_A)
print('cen: ',fit_B)
print('wid: ',fit_C)
# Out:
# amp:  30361.115025090956
# cen:  27.28066366345829
# wid:  17.36168951225111

# %% [markdown]
# # Task 5: Flattening the curve (maths for corona virus curves)

# %% [markdown]
# Mathematically, flattening the curve requires an increase in the standard deviation. Healthwise, a flatter curve leads to a lower rate of infection so the pandemic is spread out over time, thus giving health professionals a reasonable chance at treating all of the sick people with the available resources.

# %% [markdown]
# Without any measures to slow down the exponential growth, COVID-19 will continue to spread exponentially for many months. Eventually, enough people will recover from the disease to slow it’s spread. A person who has recovered from the infection will no longer spread it to a healthy person nor become sick again after coming in contact with the infection. However, if left untreated, the COVID-19 will spread throughout a population resulting in many deaths. As mentioned, such a scenario would quickly overwhelm the health care system with an exponentially increase number of infected individuals appearing in a very short time frame. This would lead to the death of many more people due to a lack of hospital beds, medicine, ventilators, and other resources.
#
# For this reason, governments have been taking protective measures such as closing all but the most required services and commercial operations. Entire cities, states and nations have closed their boarders. Individuals and businesses are in self-quarantine and/or self-isolation to avoid crowds with the goal of slowing the spread of the virus by “flattening” the infection curve.
#
# We know from history that this approach will work as well as by witnessing the recovery and limited number of deaths in China as compared to Italy. But such an approach is not without consequences as it is taking an almost depression-like toll on businesses around the world.

# %% [markdown]
# ### TO DO (all steps will be marked) :

# %% [markdown]
# * 1. Define a Gaussian curve/function,
# * 2. Generate some data
# * 3. plot three Gaussian bell curves and then lower the amplitude of each Gaussian, and also widden the width of the curves to "simulate" the flattening of a curve as shown in the image below. The intension is to model in python the famous graph of daily number of cases.
# * 4. Apply some nice graphics techniques, nice coulours for shading the region under the curve, labels.

# %% [markdown]
# https://www.designnews.com/medical/doing-coronavirus-math-exponentials-bell-curves-and-flattening/62721958762674/page/0/1

# %% [markdown]
# ![Flattening-the-curve-3_700W.png](attachment:Flattening-the-curve-3_700W.png)

# %%
import matplotlib.pyplot as plt
from numpy import exp, loadtxt, pi, sqrt
#from lmfit import Model

matplotlib.rcParams.update({'font.size': 18, 'text.usetex': True})

#Generate some data
x = np.arange(0,365)

#define a Gaussian curve
def gaussian(x, amp, cen, wid):
    """1-d gaussian: gaussian(x, amp, cen, wid)"""
    return amp*np.exp(-((x-cen)/wid)**2)

#call the Gaussian function three times we create three Models 

fig = plt.figure(figsize=(20,10))

result = gaussian(x, 170, 55, 15)
result1 = gaussian(x, 125, 125, 40)
result2 = gaussian(x, 45, 215, 40)

plt.fill(x, result, color='tomato', alpha=0.5, label='No restriction')
plt.fill(x, result1, color='darkorange', alpha=0.5, label='Minor restriction')
plt.fill(x, result2, color='yellowgreen', alpha=0.5, label='Full restriction')
plt.axhline(y=40, color='deepskyblue', linestyle='--')

plt.text(300,43,'Healthcare system capacity',color = 'deepskyblue')
plt.ylabel('Number of cases')
plt.xlabel('Days')
plt.title('Lockdown impact')
plt.xticks([])
plt.yticks([])
plt.ylim(ymin=-1)
plt.xlim(xmin=-1)
plt.legend()

plt.show()

# %% [markdown]
# # Hint for Task 4:

# %% [markdown]
# See also Section 3.2 in the Module with Statistics.

# %% [markdown]
# A common use of least-squares minimization is curve fitting, where one has
# * a parametrized model function meant to explain some phenomena and
# * wants to adjust the numerical values for the model so that it most closely matches some data.

# %% [markdown]
# With scipy, such problems are typically solved with scipy.optimize.curve_fit, which is a wrapper around scipy.optimize.leastsq.
#
# Self study: https://lmfit.github.io/lmfit-py/model.html

# %% [markdown]
# We should start with a simple definition of the model function:
#
# $p(x)=Amplitude*\exp^{\frac{ - (x - \mu)^2 }{width}} $

# %% [markdown]
# # Hint for Task 2 : An elegant  way of plotting data with reformatting dates
#
#
#
# ###    autofmt_xdate()
#
# Date ticklabels often overlap, so it is useful to rotate them and right align them.
#
# ### Fixing common date annoyances
#
#  http://www.devdoc.net/python/matplotlib-2.0.0/users/recipes.html

# %%
import matplotlib.pyplot as plt
import pandas as pd

#times = pd.date_range('2015-10-06', periods=500, freq='10min')
# Create a figure instance

fig, ax = plt.subplots(figsize=(20, 10))

# rotate and align the tick labels so they look better
fig.autofmt_xdate()


plt.plot(dates[60:140], total_cases[60:140])
ax.tick_params(axis='x', rotation=90)
plt.show()

# %% [markdown]
# The “early signs of flattening the curve” at the end of March were largely due to the drop in cases from overseas, which had already fallen 25%.

# %% [markdown]
# Second Hint for task 2: A quick way of plotting data: daily confirmed new cases.

# %%
total_cases.plot()

# %%
Quick check: Check with the current status:
        
https://www.health.gov.au/news/health-alerts/novel-coronavirus-2019-ncov-health-alert?gclid=EAIaIQobChMI7Pbn98Xp6QIVyX4rCh1vCAYYEAAYASAAEgJjUPD_BwE    https://www.google.com/aclk?sa=l&ai=DChcSEwjs9uf3xenpAhXJfisKHW8IBhgYABAAGgJzZg&sig=AOD64_11byR2Q9_eNLIPkkIPWrnCEkzwDg&q=&ved=2ahUKEwjEp973xenpAhUXxzgGHcS6AnEQ0Qx6BAgNEAE&adurl=

# %%
new_cases.plot()

# %% [markdown]
# Go back and add labels and a title to your plots! And the x-axis just shows the number of data points increasing.

# %% [markdown]
# Hint: Read the hint on elegant way of presenting reformatted dates, and the end of the worksheet.
